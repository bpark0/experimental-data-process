# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# input the file name
file_name_1 = '05242019-PCL-PTMC neat base.csv'

file_name_2 = '07122019-8 wt MgTFSI PCL-PTMC-5 base.csv'
file_name_3 = '07122019-8 wt MgTFSI PCL-PTMC-8 base.csv'
file_name_4 = '07292019-8wt MgTFSI2 PCL-PTMC (1)-1.csv'
file_name_5 = '07292019-8wt MgTFSI2 PCL-PTMC (1)-2.csv'
file_name_6 = '07292019-8wt MgTFSI2 PCL-PTMC (2)-1.csv'
file_name_7 = '07292019-8wt MgTFSI2 PCL-PTMC (2)-2.csv'
file_name_8 = '07292019-8wt MgTFSI2 PCL-PTMC (3)-1.csv'
file_name_9 = '07292019-8wt MgTFSI2 PCL-PTMC (3)-2.csv'
file_name_10 = '08052019-8wt MgTFSI PCL-PTMC (5)-1.csv'
file_name_11 = '08052019-8wt MgTFSI PCL-PTMC (6)-1.csv'
file_name_12 = '08052019-8wt MgTFSI PCL-PTMC (6)-2.csv'
file_name_13 = '08052019-8wt MgTFSI PCL-PTMC (7)-1.csv'
file_name_14 = '10042019-8 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_15 = '10042019-8 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_16 = '10042019-8 wt MgTFSI PCL-PTMC-3 base.csv'

file_name_17 = '07022019-12 wt MgTFSI P(CL-TMC)-6.csv'
file_name_18 = '07122019-12 wt MgTFSI PCL-PTMC-4 base.csv'
file_name_19 = '07122019-12 wt MgTFSI PCL-PTMC-6 base.csv'
file_name_20 = '08052019-12wt MgTFSI2 PCL-PTMC (5)-1.csv'
file_name_21 = '08052019-12wt MgTFSI2 PCL-PTMC (5)-2.csv'
file_name_22 = '08052019-12wt MgTFSI2 PCL-PTMC (6)-1.csv'
file_name_23 = '08052019-12wt MgTFSI2 PCL-PTMC (6)-2.csv'
file_name_24 = '08052019-12wt MgTFSI2 PCL-PTMC (7)-1.csv'
file_name_25 = '08052019-12wt MgTFSI2 PCL-PTMC (7)-2.csv'
file_name_26 = '10042019-12 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_27 = '10042019-12 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_28 = '10042019-12 wt MgTFSI PCL-PTMC-3 base.csv'

file_name_29 = '07122019-16 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_30 = '08052019-16wt MgTFSI PCL-PTMC (1)-1.csv'
file_name_31 = '08052019-16wt MgTFSI PCL-PTMC (2)-1.csv'
file_name_32 = '08052019-16wt MgTFSI PCL-PTMC (2)-2.csv'
file_name_33 = '08052019-16wt MgTFSI PCL-PTMC (3)-1.csv'
file_name_34 = '08052019-16wt MgTFSI PCL-PTMC-(1)-2.csv'
file_name_35 = '10042019-16 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_36 = '10042019-16 wt MgTFSI PCL-PTMC-2 base.csv'

file_name_37 = '05242019-20 wt MgTFSI2 PCL-PTMC base.csv'
file_name_38 = '07122019-20 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_39 = '07122019-20 wt MgTFSI PCL-PTMC-5 base.csv'
file_name_40 = '09052019-20 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_41 = '09052019-20 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_42 = '09052019-20 wt MgTFSI PCL-PTMC-3 base.csv'
file_name_43 = '10042019-20 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_44 = '10042019-20 wt MgTFSI PCL-PTMC-2 base.csv'

file_name_45 = '07122019-28 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_46 = '09052019-28 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_47 = '09052019-28 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_48 = '09052019-28 wt MgTFSI PCL-PTMC-3 base.csv'
file_name_49 = '09052019-28 wt MgTFSI PCL-PTMC-4 base.csv'
file_name_50 = '10042019-28 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_51 = '10042019-28 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_52 = '10042019-28 wt MgTFSI PCL-PTMC-3 base.csv'

file_name_53 = '07022019-36 wt MgTFSI P(CL-TMC)-3.csv'
file_name_54 = '07122019-36 wt MgTFSI PCL-PTMC-3 base.csv'
file_name_55 = '09052019-36 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_56 = '09052019-36 wt MgTFSI PCL-PTMC-2 base.csv'
file_name_57 = '09052019-36 wt MgTFSI PCL-PTMC-3 base.csv'
file_name_58 = '10042019-36 wt MgTFSI PCL-PTMC-1 base.csv'
file_name_59 = '10042019-36 wt MgTFSI PCL-PTMC-2 base.csv'

# define the range of data in the .csv file as the number of rows
start_of_dataset = 19
end_of_dataset = 3803

def data_process(file_name, shift = 0):
    xaxis = 'Wavenumber (cm^-1)'
    yaxis = file_name
    data = pd.read_csv(file_name, names=[xaxis,yaxis[:-4]])
    data_trim_original = data[start_of_dataset:end_of_dataset]
    data_trim_original = data_trim_original.astype(float)
    data_trim = data_trim_original.set_index(xaxis)
    data_norm = data_trim/(data_trim[600:800].max())
    data_norm = data_norm + shift
    return data_norm

# find peak ratio (functional group vs. TFSI- shift)
def find_peak_ratio(file_name, lower_limit, upper_limit):
    xaxis = 'Wavenumber (cm^-1)'
    yaxis = file_name
    data = pd.read_csv(file_name, names=[xaxis,yaxis[:-4]])
    data_trim_original = data[start_of_dataset:end_of_dataset]
    data_trim_original = data_trim_original.astype(float)
    data_trim = data_trim_original.set_index(xaxis)
    peak_ratio = (data_trim[lower_limit:upper_limit].max())/(data_trim[600:800].max())
    peak_index = data_trim[600:800].idxmax()
    return peak_ratio

def find_peak_index(file_name, lower_limit, upper_limit):
    xaxis = 'Wavenumber (cm^-1)'
    yaxis = file_name
    data = pd.read_csv(file_name, names=[xaxis,yaxis[:-4]])
    data_trim_original = data[start_of_dataset:end_of_dataset]
    data_trim_original = data_trim_original.astype(float)
    data_trim = data_trim_original.set_index(xaxis)
    peak_index = data_trim[600:800].idxmax()
    return peak_index
# Out:
# 05242019-PCL-PTMC neat base    11.035423
# dtype: float64
#  05242019-PCL-PTMC neat base    607.7512
# dtype: float64

# %%
peak_ratio_1 = find_peak_ratio(file_name_1, 1600, 1850)
peak_ratio_2 = find_peak_ratio(file_name_2, 1600, 1850)
peak_ratio_3 = find_peak_ratio(file_name_3, 1600, 1850)
peak_ratio_4 = find_peak_ratio(file_name_4, 1600, 1850)
peak_ratio_5 = find_peak_ratio(file_name_5, 1600, 1850)
peak_ratio_6 = find_peak_ratio(file_name_6, 1600, 1850)
peak_ratio_7 = find_peak_ratio(file_name_7, 1600, 1850)
peak_ratio_8 = find_peak_ratio(file_name_8, 1600, 1850)
peak_ratio_9 = find_peak_ratio(file_name_9, 1600, 1850)
peak_ratio_10 = find_peak_ratio(file_name_10, 1600, 1850)
peak_ratio_11 = find_peak_ratio(file_name_11, 1600, 1850)
peak_ratio_12 = find_peak_ratio(file_name_12, 1600, 1800)
peak_ratio_13 = find_peak_ratio(file_name_13, 1600, 1850)
peak_ratio_14 = find_peak_ratio(file_name_14, 1600, 1850)
peak_ratio_15 = find_peak_ratio(file_name_15, 1600, 1850)

peaklist = [peak_ratio_1, peak_ratio_2, peak_ratio_3,peak_ratio_4,peak_ratio_5,peak_ratio_6,peak_ratio_7,peak_ratio_8,peak_ratio_9,peak_ratio_10,peak_ratio_11, peak_ratio_12,peak_ratio_13,peak_ratio_14,peak_ratio_15]
print(peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',
     peak_ratio_1, '\n',)
# peaklist.to_csv('peaklist_LiTFSI_PCL-PTMC.csv')
# Out:
# [05242019-PCL-PTMC neat base    11.035423
# dtype: float64, 07122019-8 wt MgTFSI PCL-PTMC-5 base    0.814654
# dtype: float64, 07122019-8 wt MgTFSI PCL-PTMC-8 base    0.714958
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (1)-1    1.089294
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (1)-2    1.087309
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (2)-1    1.146682
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (2)-2    1.202892
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (3)-1    1.068332
# dtype: float64, 07292019-8wt MgTFSI2 PCL-PTMC (3)-2    1.104736
# dtype: float64, 08052019-8wt MgTFSI PCL-PTMC (5)-1    5.371663
# dtype: float64, 08052019-8wt MgTFSI PCL-PTMC (6)-1    1.065541
# dtype: float64, 08052019-8wt MgTFSI PCL-PTMC (6)-2    1.092986
# dtype: float64, 08052019-8wt MgTFSI PCL-PTMC (7)-1    0.70321
# dtype: float64, 10042019-8 wt MgTFSI PCL-PTMC-1 base    1.486868
# dtype: float64, 10042019-8 wt MgTFSI PCL-PTMC-2 base    1.500298
# dtype: float64]

# %%
# collect datasets using shift
space = 0.3
sample_num = 15
shift_1 = 0
shift_2 = shift_1 + space
shift_3 = shift_2 + space
shift_4 = shift_3 + space
shift_5 = shift_4 + space
shift_6 = shift_5 + space
shift_7 = shift_6 + space
shift_8 = shift_7 + space
shift_9 = shift_8 + space
shift_10 = shift_9 + space
shift_11 = shift_10 + space
shift_12 = shift_11 + space
shift_13 = shift_12 + space
shift_14 = shift_13 + space
shift_15 = shift_14 + space
shift_16 = shift_15 + space
shift_17 = shift_16 + space
shift_18 = shift_17 + space
shift_19 = shift_18 + space
shift_20 = shift_19 + space

dataset_1 = data_process(file_name_1, shift_1)

dataset_2 = data_process(file_name_2, shift_1)
dataset_3 = data_process(file_name_3, shift_2)
dataset_4 = data_process(file_name_4, shift_3)
dataset_5 = data_process(file_name_5, shift_4)
dataset_6 = data_process(file_name_6, shift_5)
dataset_7 = data_process(file_name_7, shift_6)
dataset_8 = data_process(file_name_8, shift_7)
dataset_9 = data_process(file_name_9, shift_8)
dataset_10 = data_process(file_name_10, shift_9)
dataset_11 = data_process(file_name_11, shift_10)
dataset_12 = data_process(file_name_12, shift_11)
dataset_13 = data_process(file_name_13, shift_12)
dataset_14 = data_process(file_name_14, shift_13)
dataset_15 = data_process(file_name_15, shift_14)
dataset_16 = data_process(file_name_16, shift_15)

dataset_17 = data_process(file_name_17, shift_1)
dataset_18 = data_process(file_name_18, shift_2)
dataset_19 = data_process(file_name_19, shift_3)
dataset_20 = data_process(file_name_20, shift_4)
dataset_21 = data_process(file_name_21, shift_5)
dataset_22 = data_process(file_name_22, shift_6)
dataset_23 = data_process(file_name_23, shift_7)
dataset_24 = data_process(file_name_24, shift_8)
dataset_25 = data_process(file_name_25, shift_9)
dataset_26 = data_process(file_name_26, shift_10)
dataset_27 = data_process(file_name_27, shift_11)
dataset_28 = data_process(file_name_28, shift_12)

dataset_29 = data_process(file_name_29, shift_1)
dataset_30 = data_process(file_name_30, shift_2)
dataset_31 = data_process(file_name_31, shift_3)
dataset_32 = data_process(file_name_32, shift_4)
dataset_33 = data_process(file_name_33, shift_5)
dataset_34 = data_process(file_name_34, shift_6)
dataset_35 = data_process(file_name_35, shift_7)
dataset_36 = data_process(file_name_36, shift_8)

dataset_37 = data_process(file_name_37, shift_1)
dataset_38 = data_process(file_name_38, shift_2)
dataset_39 = data_process(file_name_39, shift_3)
dataset_40 = data_process(file_name_40, shift_4)
dataset_41 = data_process(file_name_41, shift_5)
dataset_42 = data_process(file_name_42, shift_6)
dataset_43 = data_process(file_name_43, shift_7)
dataset_44 = data_process(file_name_44, shift_8)

dataset_45 = data_process(file_name_45, shift_1)
dataset_46 = data_process(file_name_46, shift_2)
dataset_47 = data_process(file_name_47, shift_3)
dataset_48 = data_process(file_name_48, shift_4)
dataset_49 = data_process(file_name_49, shift_5)
dataset_50 = data_process(file_name_50, shift_6)
dataset_51 = data_process(file_name_51, shift_7)
dataset_52 = data_process(file_name_52, shift_8)

dataset_53 = data_process(file_name_53, shift_1)
dataset_54 = data_process(file_name_54, shift_2)
dataset_55 = data_process(file_name_55, shift_3)
dataset_56 = data_process(file_name_56, shift_4)
dataset_57 = data_process(file_name_57, shift_5)
dataset_58 = data_process(file_name_58, shift_6)
dataset_59 = data_process(file_name_59, shift_7)

# %%
# plot datasets

# set default font style and size globally in matplotlib
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = 6.4, 9.6

ax = dataset_16.plot()
dataset_15.plot(ax=ax)
dataset_14.plot(ax=ax)
dataset_13.plot(ax=ax)
dataset_12.plot(ax=ax)
dataset_11.plot(ax=ax)
dataset_10.plot(ax=ax)
dataset_9.plot(ax=ax)
dataset_8.plot(ax=ax)
dataset_7.plot(ax=ax)
dataset_6.plot(ax=ax)
dataset_5.plot(ax=ax)
dataset_4.plot(ax=ax)
dataset_3.plot(ax=ax)
dataset_2.plot(ax=ax)

plt.legend(loc='upper left',prop={'size': 7})
plt.ylabel('Intensity (a.u.)', fontsize=15)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
#ax.set_ylabel('Intensity (a.u.)', fontsize=15)
#ax.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
# plt.xlim(1910,9) # full scale
plt.xlim(800,700) # peak scale
plt.ylim(-0.1, 2.5 + space*sample_num-1)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=5)
# plt.savefig(file_name_1[:-11]+' full.png', dpi=300) # full scale
plt.savefig(file_name_16[:-11]+' all.png', dpi=300) # peak scale
plt.show()

# %%
# plot datasets

# set default font style and size globally in matplotlib
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = 6.4, 9.6

ax = dataset_16.plot()
dataset_15.plot(ax=ax)
dataset_14.plot(ax=ax)
dataset_13.plot(ax=ax)
dataset_12.plot(ax=ax)
dataset_11.plot(ax=ax)
dataset_10.plot(ax=ax)
dataset_9.plot(ax=ax)
dataset_8.plot(ax=ax)
dataset_7.plot(ax=ax)
dataset_6.plot(ax=ax)
dataset_5.plot(ax=ax)
dataset_4.plot(ax=ax)
dataset_3.plot(ax=ax)
dataset_2.plot(ax=ax)

plt.legend(loc='upper left',prop={'size': 7})
plt.ylabel('Intensity (a.u.)', fontsize=15)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
#ax.set_ylabel('Intensity (a.u.)', fontsize=15)
#ax.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
# plt.xlim(1910,9) # full scale
plt.xlim(1850,1600) # peak scale
plt.ylim(-0.1, 5 + space*sample_num-1)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=5)
# plt.savefig(file_name_1[:-11]+' full.png', dpi=300) # full scale
plt.savefig(file_name_16[:-11]+' carbonyl.png', dpi=300) # peak scale
plt.show()

# %%
# plot datasets

# set default font style and size globally in matplotlib
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 12
plt.rcParams['figure.figsize'] = 6.4, 9.6

ax = dataset_16.plot()
dataset_15.plot(ax=ax)
dataset_14.plot(ax=ax)
dataset_13.plot(ax=ax)
dataset_12.plot(ax=ax)
dataset_11.plot(ax=ax)
dataset_10.plot(ax=ax)
dataset_9.plot(ax=ax)
dataset_8.plot(ax=ax)
dataset_7.plot(ax=ax)
dataset_6.plot(ax=ax)
dataset_5.plot(ax=ax)
dataset_4.plot(ax=ax)
dataset_3.plot(ax=ax)
dataset_2.plot(ax=ax)

plt.legend(loc='upper left',prop={'size': 11})
plt.ylabel('Intensity (a.u.)', fontsize=15)
plt.xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
#ax.set_ylabel('Intensity (a.u.)', fontsize=15)
#ax.set_xlabel('Wavenumber (cm$^{-1}$)', fontsize=15)
plt.xlim(1910,9) # full scale
# plt.xlim(800,700) # peak scale
plt.ylim(-0.1, 5 + space*sample_num)
plt.locator_params(axis='y', nbins=6)
plt.locator_params(axis='x', nbins=5)
plt.savefig(file_name_16[:-11]+' full.png', dpi=300) # full scale
# plt.savefig(file_name_1[:-11]+'.png', dpi=300) # peak scale
plt.show()
